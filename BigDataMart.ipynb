# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
urlfile="https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv"

# %%
df_1=pd.read_csv(urlfile)

# %%
#shape
df_1.shape
# Out:
# (8523, 12)

# %% [markdown]
# ## Primary Inspection

# %%
df_1.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
df_1.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ### There are few missing values in 2 columns

# %%
df=df_1.copy()

# %%
continuous_cols=df[[x for x in df.columns if df[x].nunique()>20]]

# %%
continuous_cols.head(2)
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0           FDA15         9.30         0.016047  249.8092          3735.1380
# 1           DRC01         5.92         0.019278   48.2692           443.4228

# %%
categorical_cols=df[[x for x in df.columns if df[x].nunique()<20]]

# %% [markdown]
# ## 1. Primary Inspection and Exploratory Data Analysis on Categorical Columns.

# %%
categorical_cols.head(2)
# Out:
#   Item_Fat_Content    Item_Type Outlet_Identifier  Outlet_Establishment_Year  \
# 0          Low Fat        Dairy            OUT049                       1999
# 1          Regular  Soft Drinks            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# 1      Medium               Tier 3  Supermarket Type2

# %%
for i in categorical_cols.columns:
    print('Unique Values For :',i)
    print(categorical_cols[i].unique())
# Out:
# Unique Values For : Item_Fat_Content
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# Unique Values For : Item_Type
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Unique Values For : Outlet_Identifier
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
# Unique Values For : Outlet_Establishment_Year
# [1999 2009 1998 1987 1985 2002 2007 1997 2004]
# Unique Values For : Outlet_Size
# ['Medium' nan 'High' 'Small']
# Unique Values For : Outlet_Location_Type
# ['Tier 1' 'Tier 3' 'Tier 2']
# Unique Values For : Outlet_Type
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %% [markdown]
# ### It can be seen that there are words in the Item_fat column that have same meaning but different letter formattings

# %% [markdown]
# ##  It can be seen that the Item_Fat_Content column has same categories with different formattings. Also there are nan values in the 'Outlet_Size' column.

# %%
df['Outlet_Size'].isna().sum()
# Out:
# 2410

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].apply(lambda x:'Low Fat' if x in ['low fat','LF'] else ('Regular' if x in ['reg'] else x))

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
# for i in categorical_cols.columns:
#     if df[i].nunique()>5:
#         plt.figure(figsize=(15,5))
#         sns.countplot(df[i])
#         plt.xticks(rotation=45)
#         plt.show()
#     else:
#         plt.figure(figsize=(6,5))
#         sns.countplot(df[i])
#         plt.xticks(rotation=45)
#         plt.show()
for i in categorical_cols.columns:
    if df_1[i].nunique()>=5:
        fig, axes = plt.subplots(2, 1, figsize=(18,8),sharex=True)
        sns.countplot(df_1[i],ax=axes[0])
        axes[0].tick_params(axis='x', rotation=90)
        sns.boxplot(ax=axes[1],x=df_1[i],y=df_1['Item_Outlet_Sales'])
        axes[1].tick_params(axis='x', rotation=90)
        plt.show()
    else:
        fig, axes = plt.subplots(1, 2, sharex=True, figsize=(18,5))
        sns.countplot(df_1[i],ax=axes[0])
        axes[0].tick_params(axis='x', rotation=90)
        sns.boxplot(x=df_1[i],y=df_1['Item_Outlet_Sales'],ax=axes[1])
        axes[1].tick_params(axis='x', rotation=90)
        plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=pd.get_dummies(data=df, columns=['Item_Type','Item_Fat_Content','Outlet_Type'],drop_first=True)

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_MRP Outlet_Identifier  \
# 0           FDA15         9.30         0.016047  249.8092            OUT049
# 1           DRC01         5.92         0.019278   48.2692            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
#
#    Item_Outlet_Sales  Item_Type_Breads  ...  Item_Type_Meat  Item_Type_Others  \
# 0          3735.1380                 0  ...               0                 0
# 1           443.4228                 0  ...               0                 0
#
#    Item_Type_Seafood  Item_Type_Snack Foods  Item_Type_Soft Drinks  \
# 0                  0                      0                      0
# 1                  0                      0                      1
#
#    Item_Type_Starchy Foods  Item_Fat_Content_Regular  \
# 0                        0                         0
# 1                        0                         1
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                              1                              0
# 1                              0                              1
#
#    Outlet_Type_Supermarket Type3
# 0                              0
# 1                              0
#
# [2 rows x 28 columns]

# %%
df.drop(columns=['Item_Identifier','Outlet_Size','Outlet_Identifier'],inplace=True)

# %%
df.shape
# Out:
# (8523, 25)

# %%
df['Outlet_Location_Type']=df['Outlet_Location_Type'].apply(lambda x: 1 if x in 'Tier 1' else (2 if x in 'Tier 2' else 3))

# %% [markdown]
# ## 1. Primary Inspection and Exploratory Data Analysis on Continuous Columns.

# %%
continuous_cols.head(2)
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0           FDA15         9.30         0.016047  249.8092          3735.1380
# 1           DRC01         5.92         0.019278   48.2692           443.4228

# %%
cont_cols=df[[x for x in df.columns if x  in list(continuous_cols.columns)]]

# %%
#cont_cols.drop(columns='Item_Identifier',inplace=True)

# %%
sns.pairplot(cont_cols,height=5)
sns.set(font_scale=2)

# %% [markdown]
# ### Observation: There is no linear relationship between the Item_Outlet_Sales and Item_Weight features.

# %%
cont_cols.corr()
# Out:
#                    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# Item_Weight           1.000000        -0.014048  0.027141           0.014123
# Item_Visibility      -0.014048         1.000000 -0.001315          -0.128625
# Item_MRP              0.027141        -0.001315  1.000000           0.567574
# Item_Outlet_Sales     0.014123        -0.128625  0.567574           1.000000

# %% [markdown]
# ### We can drop the Item_Weight column

# %%
df.drop(columns=['Item_Weight'],inplace=True)

# %%
df.head(2)
# Out:
#    Item_Visibility  Item_MRP  Outlet_Establishment_Year  Outlet_Location_Type  \
# 0         0.016047  249.8092                       1999                     1
# 1         0.019278   48.2692                       2009                     3
#
#    Item_Outlet_Sales  Item_Type_Breads  Item_Type_Breakfast  Item_Type_Canned  \
# 0          3735.1380                 0                    0                 0
# 1           443.4228                 0                    0                 0
#
#    Item_Type_Dairy  Item_Type_Frozen Foods  ...  Item_Type_Meat  \
# 0                1                       0  ...               0
# 1                0                       0  ...               0
#
#    Item_Type_Others  Item_Type_Seafood  Item_Type_Snack Foods  \
# 0                 0                  0                      0
# 1                 0                  0                      0
#
#    Item_Type_Soft Drinks  Item_Type_Starchy Foods  Item_Fat_Content_Regular  \
# 0                      0                        0                         0
# 1                      1                        0                         1
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                              1                              0
# 1                              0                              1
#
#    Outlet_Type_Supermarket Type3
# 0                              0
# 1                              0
#
# [2 rows x 24 columns]

# %%
#df.drop(columns='Item_Identifier',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Item_Visibility                  8523 non-null   float64
#  1   Item_MRP                         8523 non-null   float64
#  2   Outlet_Establishment_Year        8523 non-null   int64
#  3   Outlet_Location_Type             8523 non-null   int64
#  4   Item_Outlet_Sales                8523 non-null   float64
#  5   Item_Type_Breads                 8523 non-null   uint8
#  6   Item_Type_Breakfast              8523 non-null   uint8
#  7   Item_Type_Canned                 8523 non-null   uint8
#  8   Item_Type_Dairy                  8523 non-null   uint8
#  9   Item_Type_Frozen Foods           8523 non-null   uint8
#  10  Item_Type_Fruits and Vegetables  8523 non-null   uint8
#  11  Item_Type_Hard Drinks            8523 non-null   uint8
#  12  Item_Type_Health and Hygiene     8523 non-null   uint8
#  13  Item_Type_Household              8523 non-null   uint8
#  14  Item_Type_Meat                   8523 non-null   uint8
#  15  Item_Type_Others                 8523 non-null   uint8
#  16  Item_Type_Seafood                8523 non-null   uint8
#  17  Item_Type_Snack Foods            8523 non-null   uint8
#  18  Item_Type_Soft Drinks            8523 non-null   uint8
#  19  Item_Type_Starchy Foods          8523 non-null   uint8
#  20  Item_Fat_Content_Regular         8523 non-null   uint8
#  21  Outlet_Type_Supermarket Type1    8523 non-null   uint8
#  22  Outlet_Type_Supermarket Type2    8523 non-null   uint8
#  23  Outlet_Type_Supermarket Type3    8523 non-null   uint8
# dtypes: float64(3), int64(2), uint8(19)
# memory usage: 491.2 KB

# %%
X=df.drop(columns='Item_Outlet_Sales')

# %% [markdown]
# ## Checking For Multicolliniearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                             feature        VIF
# 0                   Item_Visibility   2.908302
# 1                          Item_MRP   6.204235
# 2         Outlet_Establishment_Year  39.792936
# 3              Outlet_Location_Type  11.741110
# 4                  Item_Type_Breads   1.389593
# 5               Item_Type_Breakfast   1.173064
# 6                  Item_Type_Canned   2.005728
# 7                   Item_Type_Dairy   2.067691
# 8            Item_Type_Frozen Foods   2.325597
# 9   Item_Type_Fruits and Vegetables   2.913802
# 10            Item_Type_Hard Drinks   1.363699
# 11     Item_Type_Health and Hygiene   1.885559
# 12              Item_Type_Household   2.559225
# 13                   Item_Type_Meat   1.663476
# 14                 Item_Type_Others   1.287626
# 15                Item_Type_Seafood   1.099620
# 16            Item_Type_Snack Foods   2.870400
# 17            Item_Type_Soft Drinks   1.718415
# 18          Item_Type_Starchy Foods   1.231226
# 19         Item_Fat_Content_Regular   1.878600
# 20    Outlet_Type_Supermarket Type1   6.801655
# 21    Outlet_Type_Supermarket Type2   2.188371
# 22    Outlet_Type_Supermarket Type3   2.192085

# %% [markdown]
# ### We can drop the Outlet_Establishment_Year  column as it has a VIF value of 39.

# %%
df.drop(columns=['Outlet_Establishment_Year'],inplace=True)

# %%
df['Item_Visibility']=df['Item_Visibility'].apply(np.log1p)

# %%
#df['Item_Outlet_Sales']=df['Item_Outlet_Sales'].apply(np.log1p)

# %%
df.corr()
# Out:
#                                  Item_Visibility  Item_MRP  \
# Item_Visibility                         1.000000 -0.000701
# Item_MRP                               -0.000701  1.000000
# Outlet_Location_Type                   -0.027210  0.000232
# Item_Outlet_Sales                      -0.125600  0.567574
# Item_Type_Breads                        0.000866 -0.000112
# Item_Type_Breakfast                     0.044090  0.001460
# Item_Type_Canned                        0.010816 -0.005666
# Item_Type_Dairy                         0.036394  0.035551
# Item_Type_Frozen Foods                 -0.002417 -0.013358
# Item_Type_Fruits and Vegetables         0.019072  0.023688
# Item_Type_Hard Drinks                  -0.003564 -0.010089
# Item_Type_Health and Hygiene           -0.054043 -0.041646
# Item_Type_Household                    -0.033272  0.046815
# Item_Type_Meat                         -0.017907 -0.004086
# Item_Type_Others                       -0.016509 -0.018595
# Item_Type_Seafood                       0.014593  0.001186
# Item_Type_Snack Foods                   0.006030  0.033817
# Item_Type_Soft Drinks                  -0.010062 -0.035808
# Item_Type_Starchy Foods                 0.003456  0.014613
# Item_Fat_Content_Regular                0.048045  0.006063
# Outlet_Type_Supermarket Type1          -0.140401  0.004885
# Outlet_Type_Supermarket Type2          -0.033874  0.003850
# Outlet_Type_Supermarket Type3          -0.050233 -0.006714
#
#                                  Outlet_Location_Type  Item_Outlet_Sales  \
# Item_Visibility                             -0.027210          -0.125600
# Item_MRP                                     0.000232           0.567574
# Outlet_Location_Type                         1.000000           0.089367
# Item_Outlet_Sales                            0.089367           1.000000
# Item_Type_Breads                             0.003987           0.002332
# Item_Type_Breakfast                         -0.000532          -0.004656
# Item_Type_Canned                            -0.000138           0.007387
# Item_Type_Dairy                             -0.010098           0.008858
# Item_Type_Frozen Foods                      -0.009422          -0.009482
# Item_Type_Fruits and Vegetables              0.008188           0.025950
# Item_Type_Hard Drinks                        0.001703          -0.003956
# Item_Type_Health and Hygiene                 0.011645          -0.025587
# Item_Type_Household                          0.005277           0.015701
# Item_Type_Meat                               0.003999          -0.002995
# Item_Type_Others                            -0.014576          -0.021267
# Item_Type_Seafood                           -0.005391           0.007380
# Item_Type_Snack Foods                       -0.001845           0.022782
# Item_Type_Soft Drinks                       -0.001446          -0.024040
# Item_Type_Starchy Foods                      0.006957           0.015039
# Item_Fat_Content_Regular                    -0.001598           0.018719
# Outlet_Type_Supermarket Type1               -0.472793           0.108765
# Outlet_Type_Supermarket Type2                0.381559          -0.038059
# Outlet_Type_Supermarket Type3                0.383172           0.311192
#
#                                  Item_Type_Breads  Item_Type_Breakfast  \
# Item_Visibility                          0.000866             0.044090
# Item_MRP                                -0.000112             0.001460
# Outlet_Location_Type                     0.003987            -0.000532
# Item_Outlet_Sales                        0.002332            -0.004656
# Item_Type_Breads                         1.000000            -0.019918
# Item_Type_Breakfast                     -0.019918             1.000000
# Item_Type_Canned                        -0.050010            -0.032828
# Item_Type_Dairy                         -0.051373            -0.033723
# Item_Type_Frozen Foods                  -0.058204            -0.038207
# Item_Type_Fruits and Vegetables         -0.071605            -0.047004
# Item_Type_Hard Drinks                   -0.027955            -0.018351
# Item_Type_Health and Hygiene            -0.044402            -0.029147
# Item_Type_Household                     -0.060225            -0.039533
# Item_Type_Meat                          -0.039906            -0.026195
# Item_Type_Others                        -0.024776            -0.016264
# Item_Type_Seafood                       -0.015152            -0.009946
# Item_Type_Snack Foods                   -0.070514            -0.046288
# Item_Type_Soft Drinks                   -0.040885            -0.026838
# Item_Type_Starchy Foods                 -0.023156            -0.015201
# Item_Fat_Content_Regular                 0.032643             0.065711
# Outlet_Type_Supermarket Type1           -0.006189            -0.008695
# Outlet_Type_Supermarket Type2           -0.000734             0.000077
# Outlet_Type_Supermarket Type3            0.007693            -0.003550
#
#                                  Item_Type_Canned  Item_Type_Dairy  \
# Item_Visibility                          0.010816         0.036394
# Item_MRP                                -0.005666         0.035551
# Outlet_Location_Type                    -0.000138        -0.010098
# Item_Outlet_Sales                        0.007387         0.008858
# Item_Type_Breads                        -0.050010        -0.051373
# Item_Type_Breakfast                     -0.032828        -0.033723
# Item_Type_Canned                         1.000000        -0.084670
# Item_Type_Dairy                         -0.084670         1.000000
# Item_Type_Frozen Foods                  -0.095929        -0.098544
# Item_Type_Fruits and Vegetables         -0.118015        -0.121232
# Item_Type_Hard Drinks                   -0.046074        -0.047330
# Item_Type_Health and Hygiene            -0.073181        -0.075176
# Item_Type_Household                     -0.099258        -0.101965
# Item_Type_Meat                          -0.065770        -0.067563
# Item_Type_Others                        -0.040834        -0.041947
# Item_Type_Seafood                       -0.024972        -0.025653
# Item_Type_Snack Foods                   -0.116217        -0.119386
# Item_Type_Soft Drinks                   -0.067383        -0.069220
# Item_Type_Starchy Foods                 -0.038165        -0.039205
# Item_Fat_Content_Regular                 0.073235         0.021236
# Outlet_Type_Supermarket Type1            0.001236         0.003396
# Outlet_Type_Supermarket Type2            0.010418        -0.001746
# Outlet_Type_Supermarket Type3            0.001136        -0.010817
#
#                                  Item_Type_Frozen Foods  \
# Item_Visibility                               -0.002417
# Item_MRP                                      -0.013358
# Outlet_Location_Type                          -0.009422
# Item_Outlet_Sales                             -0.009482
# Item_Type_Breads                              -0.058204
# Item_Type_Breakfast                           -0.038207
# Item_Type_Canned                              -0.095929
# Item_Type_Dairy                               -0.098544
# Item_Type_Frozen Foods                         1.000000
# Item_Type_Fruits and Vegetables               -0.137352
# Item_Type_Hard Drinks                         -0.053624
# Item_Type_Health and Hygiene                  -0.085173
# Item_Type_Household                           -0.115523
# Item_Type_Meat                                -0.076547
# Item_Type_Others                              -0.047525
# Item_Type_Seafood                             -0.029064
# Item_Type_Snack Foods                         -0.135260
# Item_Type_Soft Drinks                         -0.078425
# Item_Type_Starchy Foods                       -0.044418
# Item_Fat_Content_Regular                       0.085041
# Outlet_Type_Supermarket Type1                  0.009750
# Outlet_Type_Supermarket Type2                 -0.001507
# Outlet_Type_Supermarket Type3                 -0.006128
#
#                                  Item_Type_Fruits and Vegetables  ...  \
# Item_Visibility                                         0.019072  ...
# Item_MRP                                                0.023688  ...
# Outlet_Location_Type                                    0.008188  ...
# Item_Outlet_Sales                                       0.025950  ...
# Item_Type_Breads                                       -0.071605  ...
# Item_Type_Breakfast                                    -0.047004  ...
# Item_Type_Canned                                       -0.118015  ...
# Item_Type_Dairy                                        -0.121232  ...
# Item_Type_Frozen Foods                                 -0.137352  ...
# Item_Type_Fruits and Vegetables                         1.000000  ...
# Item_Type_Hard Drinks                                  -0.065970  ...
# Item_Type_Health and Hygiene                           -0.104782  ...
# Item_Type_Household                                    -0.142120  ...
# Item_Type_Meat                                         -0.094171  ...
# Item_Type_Others                                       -0.058467  ...
# Item_Type_Seafood                                      -0.035755  ...
# Item_Type_Snack Foods                                  -0.166402  ...
# Item_Type_Soft Drinks                                  -0.096481  ...
# Item_Type_Starchy Foods                                -0.054645  ...
# Item_Fat_Content_Regular                                0.116955  ...
# Outlet_Type_Supermarket Type1                          -0.000811  ...
# Outlet_Type_Supermarket Type2                           0.000919  ...
# Outlet_Type_Supermarket Type3                           0.005173  ...
#
#                                  Item_Type_Meat  Item_Type_Others  \
# Item_Visibility                       -0.017907         -0.016509
# Item_MRP                              -0.004086         -0.018595
# Outlet_Location_Type                   0.003999         -0.014576
# Item_Outlet_Sales                     -0.002995         -0.021267
# Item_Type_Breads                      -0.039906         -0.024776
# Item_Type_Breakfast                   -0.026195         -0.016264
# Item_Type_Canned                      -0.065770         -0.040834
# Item_Type_Dairy                       -0.067563         -0.041947
# Item_Type_Frozen Foods                -0.076547         -0.047525
# Item_Type_Fruits and Vegetables       -0.094171         -0.058467
# Item_Type_Hard Drinks                 -0.036765         -0.022826
# Item_Type_Health and Hygiene          -0.058396         -0.036255
# Item_Type_Household                   -0.079204         -0.049174
# Item_Type_Meat                         1.000000         -0.032584
# Item_Type_Others                      -0.032584          1.000000
# Item_Type_Seafood                     -0.019927         -0.012372
# Item_Type_Snack Foods                 -0.092737         -0.057576
# Item_Type_Soft Drinks                 -0.053769         -0.033383
# Item_Type_Starchy Foods               -0.030454         -0.018908
# Item_Fat_Content_Regular               0.118574         -0.104988
# Outlet_Type_Supermarket Type1         -0.023912         -0.006344
# Outlet_Type_Supermarket Type2         -0.000476          0.004320
# Outlet_Type_Supermarket Type3          0.016172         -0.009533
#
#                                  Item_Type_Seafood  Item_Type_Snack Foods  \
# Item_Visibility                           0.014593               0.006030
# Item_MRP                                  0.001186               0.033817
# Outlet_Location_Type                     -0.005391              -0.001845
# Item_Outlet_Sales                         0.007380               0.022782
# Item_Type_Breads                         -0.015152              -0.070514
# Item_Type_Breakfast                      -0.009946              -0.046288
# Item_Type_Canned                         -0.024972              -0.116217
# Item_Type_Dairy                          -0.025653              -0.119386
# Item_Type_Frozen Foods                   -0.029064              -0.135260
# Item_Type_Fruits and Vegetables          -0.035755              -0.166402
# Item_Type_Hard Drinks                    -0.013959              -0.064965
# Item_Type_Health and Hygiene             -0.022172              -0.103186
# Item_Type_Household                      -0.030073              -0.139955
# Item_Type_Meat                           -0.019927              -0.092737
# Item_Type_Others                         -0.012372              -0.057576
# Item_Type_Seafood                         1.000000              -0.035211
# Item_Type_Snack Foods                    -0.035211               1.000000
# Item_Type_Soft Drinks                    -0.020415              -0.095011
# Item_Type_Starchy Foods                  -0.011563              -0.053813
# Item_Fat_Content_Regular                  0.012594               0.059848
# Outlet_Type_Supermarket Type1            -0.005367              -0.000154
# Outlet_Type_Supermarket Type2             0.000138               0.001453
# Outlet_Type_Supermarket Type3            -0.000091               0.005782
#
#                                  Item_Type_Soft Drinks  \
# Item_Visibility                              -0.010062
# Item_MRP                                     -0.035808
# Outlet_Location_Type                         -0.001446
# Item_Outlet_Sales                            -0.024040
# Item_Type_Breads                             -0.040885
# Item_Type_Breakfast                          -0.026838
# Item_Type_Canned                             -0.067383
# Item_Type_Dairy                              -0.069220
# Item_Type_Frozen Foods                       -0.078425
# Item_Type_Fruits and Vegetables              -0.096481
# Item_Type_Hard Drinks                        -0.037667
# Item_Type_Health and Hygiene                 -0.059828
# Item_Type_Household                          -0.081147
# Item_Type_Meat                               -0.053769
# Item_Type_Others                             -0.033383
# Item_Type_Seafood                            -0.020415
# Item_Type_Snack Foods                        -0.095011
# Item_Type_Soft Drinks                         1.000000
# Item_Type_Starchy Foods                      -0.031201
# Item_Fat_Content_Regular                     -0.094875
# Outlet_Type_Supermarket Type1                 0.009777
# Outlet_Type_Supermarket Type2                -0.004153
# Outlet_Type_Supermarket Type3                -0.006443
#
#                                  Item_Type_Starchy Foods  \
# Item_Visibility                                 0.003456
# Item_MRP                                        0.014613
# Outlet_Location_Type                            0.006957
# Item_Outlet_Sales                               0.015039
# Item_Type_Breads                               -0.023156
# Item_Type_Breakfast                            -0.015201
# Item_Type_Canned                               -0.038165
# Item_Type_Dairy                                -0.039205
# Item_Type_Frozen Foods                         -0.044418
# Item_Type_Fruits and Vegetables                -0.054645
# Item_Type_Hard Drinks                          -0.021334
# Item_Type_Health and Hygiene                   -0.033885
# Item_Type_Household                            -0.045960
# Item_Type_Meat                                 -0.030454
# Item_Type_Others                               -0.018908
# Item_Type_Seafood                              -0.011563
# Item_Type_Snack Foods                          -0.053813
# Item_Type_Soft Drinks                          -0.031201
# Item_Type_Starchy Foods                         1.000000
# Item_Fat_Content_Regular                        0.025945
# Outlet_Type_Supermarket Type1                   0.013516
# Outlet_Type_Supermarket Type2                   0.002553
# Outlet_Type_Supermarket Type3                  -0.006427
#
#                                  Item_Fat_Content_Regular  \
# Item_Visibility                                  0.048045
# Item_MRP                                         0.006063
# Outlet_Location_Type                            -0.001598
# Item_Outlet_Sales                                0.018719
# Item_Type_Breads                                 0.032643
# Item_Type_Breakfast                              0.065711
# Item_Type_Canned                                 0.073235
# Item_Type_Dairy                                  0.021236
# Item_Type_Frozen Foods                           0.085041
# Item_Type_Fruits and Vegetables                  0.116955
# Item_Type_Hard Drinks                           -0.118461
# Item_Type_Health and Hygiene                    -0.188156
# Item_Type_Household                             -0.255203
# Item_Type_Meat                                   0.118574
# Item_Type_Others                                -0.104988
# Item_Type_Seafood                                0.012594
# Item_Type_Snack Foods                            0.059848
# Item_Type_Soft Drinks                           -0.094875
# Item_Type_Starchy Foods                          0.025945
# Item_Fat_Content_Regular                         1.000000
# Outlet_Type_Supermarket Type1                    0.000533
# Outlet_Type_Supermarket Type2                    0.002129
# Outlet_Type_Supermarket Type3                    0.000183
#
#                                  Outlet_Type_Supermarket Type1  \
# Item_Visibility                                      -0.140401
# Item_MRP                                              0.004885
# Outlet_Location_Type                                 -0.472793
# Item_Outlet_Sales                                     0.108765
# Item_Type_Breads                                     -0.006189
# Item_Type_Breakfast                                  -0.008695
# Item_Type_Canned                                      0.001236
# Item_Type_Dairy                                       0.003396
# Item_Type_Frozen Foods                                0.009750
# Item_Type_Fruits and Vegetables                      -0.000811
# Item_Type_Hard Drinks                                 0.007837
# Item_Type_Health and Hygiene                         -0.005422
# Item_Type_Household                                   0.001234
# Item_Type_Meat                                       -0.023912
# Item_Type_Others                                     -0.006344
# Item_Type_Seafood                                    -0.005367
# Item_Type_Snack Foods                                -0.000154
# Item_Type_Soft Drinks                                 0.009777
# Item_Type_Starchy Foods                               0.013516
# Item_Fat_Content_Regular                              0.000533
# Outlet_Type_Supermarket Type1                         1.000000
# Outlet_Type_Supermarket Type2                        -0.480943
# Outlet_Type_Supermarket Type3                        -0.482977
#
#                                  Outlet_Type_Supermarket Type2  \
# Item_Visibility                                      -0.033874
# Item_MRP                                              0.003850
# Outlet_Location_Type                                  0.381559
# Item_Outlet_Sales                                    -0.038059
# Item_Type_Breads                                     -0.000734
# Item_Type_Breakfast                                   0.000077
# Item_Type_Canned                                      0.010418
# Item_Type_Dairy                                      -0.001746
# Item_Type_Frozen Foods                               -0.001507
# Item_Type_Fruits and Vegetables                       0.000919
# Item_Type_Hard Drinks                                -0.003132
# Item_Type_Health and Hygiene                          0.002174
# Item_Type_Household                                  -0.004979
# Item_Type_Meat                                       -0.000476
# Item_Type_Others                                      0.004320
# Item_Type_Seafood                                     0.000138
# Item_Type_Snack Foods                                 0.001453
# Item_Type_Soft Drinks                                -0.004153
# Item_Type_Starchy Foods                               0.002553
# Item_Fat_Content_Regular                              0.002129
# Outlet_Type_Supermarket Type1                        -0.480943
# Outlet_Type_Supermarket Type2                         1.000000
# Outlet_Type_Supermarket Type3                        -0.122702
#
#                                  Outlet_Type_Supermarket Type3
# Item_Visibility                                      -0.050233
# Item_MRP                                             -0.006714
# Outlet_Location_Type                                  0.383172
# Item_Outlet_Sales                                     0.311192
# Item_Type_Breads                                      0.007693
# Item_Type_Breakfast                                  -0.003550
# Item_Type_Canned                                      0.001136
# Item_Type_Dairy                                      -0.010817
# Item_Type_Frozen Foods                               -0.006128
# Item_Type_Fruits and Vegetables                       0.005173
# Item_Type_Hard Drinks                                -0.001143
# Item_Type_Health and Hygiene                          0.004634
# Item_Type_Household                                  -0.001009
# Item_Type_Meat                                        0.016172
# Item_Type_Others                                     -0.009533
# Item_Type_Seafood                                    -0.000091
# Item_Type_Snack Foods                                 0.005782
# Item_Type_Soft Drinks                                -0.006443
# Item_Type_Starchy Foods                              -0.006427
# Item_Fat_Content_Regular                              0.000183
# Outlet_Type_Supermarket Type1                        -0.482977
# Outlet_Type_Supermarket Type2                        -0.122702
# Outlet_Type_Supermarket Type3                         1.000000
#
# [23 rows x 23 columns]

# %%
X=df.drop(columns='Item_Outlet_Sales')
y=df['Item_Outlet_Sales']

# %%
X.shape, y.shape
# Out:
# ((8523, 22), (8523,))

# %%
y.unique()
# Out:
# array([3735.138 ,  443.4228, 2097.27  , ..., 7182.6504, 3608.636 ,
#        2778.3834])

# %% [markdown]
# ## Applying The Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score, r2_score

# %%
X_train, X_test, y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=50)

# %%
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 1284313.1986784523

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.5616090180243907

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.5634340353829281

# %% [markdown]
# # 2. Lasso with GridSearchCV

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[0.1,0.01,0.001,1,10,100,0.0001], 'random_state':range(1,10)}
lasso_lr=Lasso()
gscv=GridSearchCV(lasso_lr,param_grid=parameters, cv=5)
gscv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 0.01, 0.001, 1, 10, 100, 0.0001],
#                          'random_state': range(1, 10)})

# %%
gscv.best_params_
# Out:
# {'alpha': 10, 'random_state': 1}

# %%
y_train_pred=gscv.predict(X_train)
y_test_pred=gscv.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.5608353196907891

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.5650571510811697

# %%
lr=Lasso(alpha=0.01)
lr.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.01)

# %%
lr.coef_
# Out:
# array([-1.09470547e+01,  9.63911217e+02,  5.33882165e+00, -7.12661134e+00,
#        -1.94596279e+01, -3.08498261e+00, -1.97848846e+01, -1.46210714e+01,
#         9.72465155e+00,  4.49338003e+00, -9.89319262e-01, -2.00408785e+01,
#        -9.39689050e+00, -1.55548925e+00,  2.96669970e+01, -1.97354374e+01,
#        -1.15752918e+01,  3.02377819e+00,  2.90678738e+01,  9.26261807e+02,
#         4.98900163e+02,  1.05727847e+03])

# %%
columns_to_r=pd.DataFrame(zip(X.columns,lr.coef_), columns=['Columns','Coefficients'])

# %%
columns_to_keep=columns_to_r[columns_to_r['Coefficients']!=0]['Columns']

# %%
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)

# %% [markdown]
# # 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(criterion='mse',max_depth=8,random_state=42,max_features=13,min_samples_split=3,ccp_alpha=3)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=3, max_depth=8, max_features=13,
#                       min_samples_split=3, random_state=42)

# %%
y_train_pred=dt.predict(X_train)
y_test_pred=dt.predict(X_test)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.619351010017364

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.5607443560060513

# %% [markdown]
# ## 4. XGBoost Regressor

# %%
#! pip install xgboost

# %%
from xgboost import XGBRFRegressor

# %%
regressor_xgb = XGBRFRegressor(max_depth=8,random_state=42,min_child_weight=10,subsample=0.5)
regressor_xgb.fit(X_train, y_train)
y_train_pred = regressor_xgb.predict(X_train)
y_test_pred = regressor_xgb.predict(X_test)
round(r2_score(y_train, y_train_pred),4)
# Out:
# 0.6394

# %%
round(r2_score(y_test, y_test_pred),4)
# Out:
# 0.6015

# %% [markdown]
# # Conclusion: XGBoost gives the highest r2 score of 0.60 for test set.
